# %%
# !git clone https://github.com/DragMaid/DP-AR-Hair.git
# Out:
# Cloning into 'DP-AR-Hair'...
# remote: Enumerating objects: 805, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 805 (delta 48), reused 49 (delta 22), pack-reused 690 (from 1)
# Receiving objects: 100% (805/805), 126.34 MiB | 23.32 MiB/s, done.
# Resolving deltas: 100% (190/190), done.

# %%
# %cd DP-AR-Hair
# Out:
# /content/DP-AR-Hair

# %%
# !git fetch
# !git checkout feature/hair-fast-gan
# Out:
# Branch 'feature/hair-fast-gan' set up to track remote branch 'feature/hair-fast-gan' from 'origin'.
# Switched to a new branch 'feature/hair-fast-gan'

# %%
# !wget https://github.com/ninja-build/ninja/releases/download/v1.8.2/ninja-linux.zip -O /tmp/ninja.zip
# !sudo unzip -o /tmp/ninja.zip -d /usr/local/bin/
# !sudo update-alternatives --install /usr/bin/ninja ninja /usr/local/bin/ninja 1 --force
# Out:
# --2025-11-29 09:02:52--  https://github.com/ninja-build/ninja/releases/download/v1.8.2/ninja-linux.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# Make sure Poetry is installed
# !pip install poetry --quiet

# Make sure
# !poetry config virtualenvs.in-project true

# Install dependencies
# !poetry install --with full --no-interaction
# Out:
# Installing dependencies from lock file
#
# No dependencies to install or update

# %%
# !poetry add matplotlib
# Out:
# The following packages are already present in the pyproject.toml and will be skipped:
#
#   - matplotlib
#
# If you want to update it to the latest compatible version, you can use `poetry update package`.
# If you prefer to upgrade it to the latest available version, you can use `poetry add package@latest`.
#
# Nothing to add.

# %%
import os
import sys

# Path to the poetry venv
venv_path = "./.venv"

# Prepend venv's bin to PATH
os.environ["PATH"] = f"{venv_path}/bin:" + os.environ["PATH"]

os.environ["PYTHONPATH"] = "src:libs"

sys.executable  # should now be in .venv/bin/python

os.environ["MPLBACKEND"] = "Agg"

# !python src/demos/gan_iiht.py
# Out:
# Loading StyleGAN2 from checkpoint: pretrained_models/StyleGAN/ffhq.pt
# Loading e4e over the pSp framework from checkpoint: pretrained_models/encoder4editing/e4e_ffhq_encode.pt
# Network [SPADEGenerator] was created. Total number of parameters: 266.9 million. To see the architecture, do print(network).
# [INFO] Running alignment...
# Number of faces detected: 2, get largest face
# Number of faces detected: 1
# Number of faces detected: 1
# /content/DP-AR-Hair/libs/hair_gan/models/sean_codes/models/pix2pix_model.py:145: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   input_label = self.FloatTensor(bs, nc, h, w).zero_()
# ...
